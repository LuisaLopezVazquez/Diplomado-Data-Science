# %% [markdown]
# <h2><font color="#004D7F" size=6>Módulo 4. Machine Learning</font></h2>
#
#
#
# <h1><font color="#004D7F" size=4> Tecnica de imputación multiple usando mice</font></h1>
#
# <br>
# <div style="text-align: right">
# <font color="#004D7F" size=3>Luisa López Vázquez</font><br>
# <font color="#004D7F" size=3>Diplomado en Ciencia de Datos</font><br>

# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install impyute

# %%
from impyute.imputation.cs import mice
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('kidney_disease.csv')

# %%
cols_names={"bp":"blood_pressure",
          "sg":"specific_gravity",
          "al":"albumin",
          "su":"sugar",
          "rbc":"red_blood_cells",
          "pc":"pus_cell",
          "pcc":"pus_cell_clumps",
          "ba":"bacteria",
          "bgr":"blood_glucose_random",
          "bu":"blood_urea",
          "sc":"serum_creatinine",
          "sod":"sodium",
          "pot":"potassium",
          "hemo":"haemoglobin",
          "pcv":"packed_cell_volume",
          "wc":"white_blood_cell_count",
          "rc":"red_blood_cell_count",
          "htn":"hypertension",
          "dm":"diabetes_mellitus",
          "cad":"coronary_artery_disease",
          "appet":"appetite",
          "pe":"pedal_edema",
          "ane":"anemia"}

df.rename(columns=cols_names, inplace=True)

# %%
cols_names
# Out:
# {'bp': 'blood_pressure',
#  'sg': 'specific_gravity',
#  'al': 'albumin',
#  'su': 'sugar',
#  'rbc': 'red_blood_cells',
#  'pc': 'pus_cell',
#  'pcc': 'pus_cell_clumps',
#  'ba': 'bacteria',
#  'bgr': 'blood_glucose_random',
#  'bu': 'blood_urea',
#  'sc': 'serum_creatinine',
#  'sod': 'sodium',
#  'pot': 'potassium',
#  'hemo': 'haemoglobin',
#  'pcv': 'packed_cell_volume',
#  'wc': 'white_blood_cell_count',
#  'rc': 'red_blood_cell_count',
#  'htn': 'hypertension',
#  'dm': 'diabetes_mellitus',
#  'cad': 'coronary_artery_disease',
#  'appet': 'appetite',
#  'pe': 'pedal_edema',
#  'ane': 'anemia'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
#  14  potassium                312 non-null    float64
#  15  haemoglobin              348 non-null    float64
#  16  packed_cell_volume       330 non-null    object
#  17  white_blood_cell_count   295 non-null    object
#  18  red_blood_cell_count     270 non-null    object
#  19  hypertension             398 non-null    object
#  20  diabetes_mellitus        398 non-null    object
#  21  coronary_artery_disease  398 non-null    object
#  22  appetite                 399 non-null    object
#  23  pedal_edema              399 non-null    object
#  24  anemia                   399 non-null    object
#  25  classification           400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
#Convertimos a numericas las columnas 
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'], errors='coerce')
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors='coerce')
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood_glucose_random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
#  14  potassium                312 non-null    float64
#  15  haemoglobin              348 non-null    float64
#  16  packed_cell_volume       329 non-null    float64
#  17  white_blood_cell_count   294 non-null    float64
#  18  red_blood_cell_count     269 non-null    float64
#  19  hypertension             398 non-null    object
#  20  diabetes_mellitus        398 non-null    object
#  21  coronary_artery_disease  398 non-null    object
#  22  appetite                 399 non-null    object
#  23  pedal_edema              399 non-null    object
#  24  anemia                   399 non-null    object
#  25  classification           400 non-null    object
# dtypes: float64(14), int64(1), object(11)
# memory usage: 81.4+ KB

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                44.0                  7800.0                   5.2
# 1                38.0                  6000.0                   NaN
# 2                31.0                  7500.0                   NaN
# 3                32.0                  6700.0                   3.9
# 4                35.0                  7300.0                   4.6
#
#    hypertension  diabetes_mellitus  coronary_artery_disease  appetite  \
# 0           yes                yes                       no      good
# 1            no                 no                       no      good
# 2            no                yes                       no      poor
# 3           yes                 no                       no      poor
# 4            no                 no                       no      good
#
#    pedal_edema anemia classification
# 0           no     no            ckd
# 1           no     no            ckd
# 2           no    yes            ckd
# 3          yes    yes            ckd
# 4           no     no            ckd
#
# [5 rows x 25 columns]

# %%
#Creamos el ciclo
numerical_features=[]  #Guardar los valores que son numericos
categorical_features=[] # Guardar los valores que son categoricos

for i in df.drop('classification', axis=1).columns:
    
    if df[i].nunique()>7:
        numerical_features.append(i)
        print(numerical_features,i)
    else:
        categorical_features.append(i)
        print(categorical_features,i)
# Out:
# ['age'] age
# ['age', 'blood_pressure'] blood_pressure
# ['specific_gravity'] specific_gravity
# ['specific_gravity', 'albumin'] albumin
# ['specific_gravity', 'albumin', 'sugar'] sugar
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells'] red_blood_cells
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell'] pus_cell
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps'] pus_cell_clumps
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria'] bacteria
# ['age', 'blood_pressure', 'blood_glucose_random'] blood_glucose_random
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea'] blood_urea
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine'] serum_creatinine
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium'] sodium
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium'] potassium
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium', 'haemoglobin'] haemoglobin
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium', 'haemoglobin', 'packed_cell_volume'] packed_cell_volume
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count'] white_blood_cell_count
# ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count'] red_blood_cell_count
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension'] hypertension
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus'] diabetes_mellitus
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus', 'coronary_artery_disease'] coronary_artery_disease
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite'] appetite
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'pedal_edema'] pedal_edema
# ['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'pedal_edema', 'anemia'] anemia

# %%
numerical_features
# Out:
# ['age',
#  'blood_pressure',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
categorical_features
# Out:
# ['specific_gravity',
#  'albumin',
#  'sugar',
#  'red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'pedal_edema',
#  'anemia']

# %%
#Replazar  valores incorrectos
df['diabetes_mellitus'] = df['diabetes_mellitus'].replace(to_replace = {'\tno':'no','\tyes':'yes',' yes':'yes'})
df['coronary_artery_disease'] = df['coronary_artery_disease'].replace(to_replace = '\tno', value='no')
df['classification'] = df['classification'].replace(to_replace = 'ckd\t', value = 'ckd')

# %%
#Mostramos la suma de los datos nulos que tenemos en nuestra lista de caracteristicas categoricas
df.loc[:,categorical_features].isnull().sum().sort_values(ascending=False)
# Out:
# red_blood_cells            152
# pus_cell                    65
# sugar                       49
# specific_gravity            47
# albumin                     46
# pus_cell_clumps              4
# bacteria                     4
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# pedal_edema                  1
# anemia                       1
# dtype: int64

# %%
#Mostramos la suma de los datos nulos que tenemos en nuestra lista de caracteristicas numericas
df.loc[:,numerical_features].isnull().sum().sort_values(ascending=False)
# Out:
# red_blood_cell_count      131
# white_blood_cell_count    106
# potassium                  88
# sodium                     87
# packed_cell_volume         71
# haemoglobin                52
# blood_glucose_random       44
# blood_urea                 19
# serum_creatinine           17
# blood_pressure             12
# age                         9
# dtype: int64

# %%
#Eliminamos classification
df_v2=df.drop('classification', axis=1)

# %%
df.head(10)
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
# 5  60.0            90.0             1.015      3.0    0.0             NaN
# 6  68.0            70.0             1.010      0.0    0.0             NaN
# 7  24.0             NaN             1.015      2.0    4.0          normal
# 8  52.0           100.0             1.015      3.0    0.0          normal
# 9  53.0            90.0             1.020      2.0    0.0        abnormal
#
#    pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
# 5       NaN      notpresent  notpresent                  74.0  ...
# 6    normal      notpresent  notpresent                 100.0  ...
# 7  abnormal      notpresent  notpresent                 410.0  ...
# 8  abnormal         present  notpresent                 138.0  ...
# 9  abnormal         present  notpresent                  70.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                44.0                  7800.0                   5.2
# 1                38.0                  6000.0                   NaN
# 2                31.0                  7500.0                   NaN
# 3                32.0                  6700.0                   3.9
# 4                35.0                  7300.0                   4.6
# 5                39.0                  7800.0                   4.4
# 6                36.0                     NaN                   NaN
# 7                44.0                  6900.0                   5.0
# 8                33.0                  9600.0                   4.0
# 9                29.0                 12100.0                   3.7
#
#    hypertension  diabetes_mellitus  coronary_artery_disease  appetite  \
# 0           yes                yes                       no      good
# 1            no                 no                       no      good
# 2            no                yes                       no      poor
# 3           yes                 no                       no      poor
# 4            no                 no                       no      good
# 5           yes                yes                       no      good
# 6            no                 no                       no      good
# 7            no                yes                       no      good
# 8           yes                yes                       no      good
# 9           yes                yes                       no      poor
#
#    pedal_edema anemia classification
# 0           no     no            ckd
# 1           no     no            ckd
# 2           no    yes            ckd
# 3          yes    yes            ckd
# 4           no     no            ckd
# 5          yes     no            ckd
# 6           no     no            ckd
# 7          yes     no            ckd
# 8           no    yes            ckd
# 9           no    yes            ckd
#
# [10 rows x 25 columns]

# %%
df_v2
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
#      pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0      normal      notpresent  notpresent                 121.0  ...
# 1      normal      notpresent  notpresent                   NaN  ...
# 2      normal      notpresent  notpresent                 423.0  ...
# 3    abnormal         present  notpresent                 117.0  ...
# 4      normal      notpresent  notpresent                 106.0  ...
# ..        ...             ...         ...                   ...  ...
# 395    normal      notpresent  notpresent                 140.0  ...
# 396    normal      notpresent  notpresent                  75.0  ...
# 397    normal      notpresent  notpresent                 100.0  ...
# 398    normal      notpresent  notpresent                 114.0  ...
# 399    normal      notpresent  notpresent                 131.0  ...
#
#      haemoglobin  packed_cell_volume  white_blood_cell_count  \
# 0           15.4                44.0                  7800.0
# 1           11.3                38.0                  6000.0
# 2            9.6                31.0                  7500.0
# 3           11.2                32.0                  6700.0
# 4           11.6                35.0                  7300.0
# ..           ...                 ...                     ...
# 395         15.7                47.0                  6700.0
# 396         16.5                54.0                  7800.0
# 397         15.8                49.0                  6600.0
# 398         14.2                51.0                  7200.0
# 399         15.8                53.0                  6800.0
#
#      red_blood_cell_count  hypertension  diabetes_mellitus  \
# 0                     5.2           yes                yes
# 1                     NaN            no                 no
# 2                     NaN            no                yes
# 3                     3.9           yes                 no
# 4                     4.6            no                 no
# ..                    ...           ...                ...
# 395                   4.9            no                 no
# 396                   6.2            no                 no
# 397                   5.4            no                 no
# 398                   5.9            no                 no
# 399                   6.1            no                 no
#
#      coronary_artery_disease  appetite pedal_edema anemia
# 0                         no      good          no     no
# 1                         no      good          no     no
# 2                         no      poor          no    yes
# 3                         no      poor         yes    yes
# 4                         no      good          no     no
# ..                       ...       ...         ...    ...
# 395                       no      good          no     no
# 396                       no      good          no     no
# 397                       no      good          no     no
# 398                       no      good          no     no
# 399                       no      good          no     no
#
# [400 rows x 24 columns]

# %%
df_entrenamiento = df_v2.loc[:300,]
df_pruebas = df_v2.loc[300:,]

# %%
df_entrenamiento.shape
# Out:
# (301, 24)

# %%
df_pruebas.shape
# Out:
# (100, 24)

# %% [markdown]
# ## Imputación de características numéricas usando MICE

# %%
# MICE requiere valores flotantes
# Convertimos las caracteristicas numericas a flotantes
df_entrenamiento_numericos =  df_entrenamiento.loc[:,numerical_features].astype('float64')

# %%
df_entrenamiento_numericos.head(2)
# Out:
#     age  blood_pressure  blood_glucose_random  blood_urea  serum_creatinine  \
# 0  48.0            80.0                 121.0        36.0               1.2
# 1   7.0            50.0                   NaN        18.0               0.8
#
#    sodium  potassium  haemoglobin  packed_cell_volume  white_blood_cell_count  \
# 0     NaN        NaN         15.4                44.0                  7800.0
# 1     NaN        NaN         11.3                38.0                  6000.0
#
#    red_blood_cell_count
# 0                   5.2
# 1                   NaN

# %%
# Pasar las matrices numpy a los mice
df_entrenamiento_numericas_imputacion= mice(df_entrenamiento_numericos.values) # Le pasamo el data frame para la imputacion

# %%
#Vemos cuantas valores nulos tenemos en nuestro dataFrame

# %%
#Ahora a nuestro dataFrame original le vamos a pasar los valores que 
# se obtuvieron de hacer la inputacion con mice
df_entrenamiento.loc[:,numerical_features] = df_entrenamiento_numericas_imputacion

# %%
#Imprimimos para ver el resultado final
df_entrenamiento.loc[:,numerical_features].isna().sum().sort_values(ascending=False)
# Out:
# age                       0
# blood_pressure            0
# blood_glucose_random      0
# blood_urea                0
# serum_creatinine          0
# sodium                    0
# potassium                 0
# haemoglobin               0
# packed_cell_volume        0
# white_blood_cell_count    0
# red_blood_cell_count      0
# dtype: int64

# %%
df_entrenamiento.head(20)
# Out:
#      age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0   48.0       80.000000             1.020      1.0    0.0             NaN
# 1    7.0       50.000000             1.020      4.0    0.0             NaN
# 2   62.0       80.000000             1.010      2.0    3.0          normal
# 3   48.0       70.000000             1.005      4.0    0.0          normal
# 4   51.0       80.000000             1.010      2.0    0.0          normal
# 5   60.0       90.000000             1.015      3.0    0.0             NaN
# 6   68.0       70.000000             1.010      0.0    0.0             NaN
# 7   24.0       76.355856             1.015      2.0    4.0          normal
# 8   52.0      100.000000             1.015      3.0    0.0          normal
# 9   53.0       90.000000             1.020      2.0    0.0        abnormal
# 10  50.0       60.000000             1.010      2.0    4.0             NaN
# 11  63.0       70.000000             1.010      3.0    0.0        abnormal
# 12  68.0       70.000000             1.015      3.0    1.0             NaN
# 13  68.0       70.000000               NaN      NaN    NaN             NaN
# 14  68.0       80.000000             1.010      3.0    2.0          normal
# 15  40.0       80.000000             1.015      3.0    0.0             NaN
# 16  47.0       70.000000             1.015      2.0    0.0             NaN
# 17  47.0       80.000000               NaN      NaN    NaN             NaN
# 18  60.0      100.000000             1.025      0.0    3.0             NaN
# 19  62.0       60.000000             1.015      1.0    0.0             NaN
#
#     pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0     normal      notpresent  notpresent             121.00000  ...
# 1     normal      notpresent  notpresent              99.78702  ...
# 2     normal      notpresent  notpresent             423.00000  ...
# 3   abnormal         present  notpresent             117.00000  ...
# 4     normal      notpresent  notpresent             106.00000  ...
# 5        NaN      notpresent  notpresent              74.00000  ...
# 6     normal      notpresent  notpresent             100.00000  ...
# 7   abnormal      notpresent  notpresent             410.00000  ...
# 8   abnormal         present  notpresent             138.00000  ...
# 9   abnormal         present  notpresent              70.00000  ...
# 10  abnormal         present  notpresent             490.00000  ...
# 11  abnormal         present  notpresent             380.00000  ...
# 12    normal         present  notpresent             208.00000  ...
# 13       NaN      notpresent  notpresent              98.00000  ...
# 14  abnormal         present     present             157.00000  ...
# 15    normal      notpresent  notpresent              76.00000  ...
# 16    normal      notpresent  notpresent              99.00000  ...
# 17       NaN      notpresent  notpresent             114.00000  ...
# 18    normal      notpresent  notpresent             263.00000  ...
# 19  abnormal         present  notpresent             100.00000  ...
#
#     haemoglobin  packed_cell_volume  white_blood_cell_count  \
# 0          15.4           44.000000             7800.000000
# 1          11.3           38.000000             6000.000000
# 2           9.6           31.000000             7500.000000
# 3          11.2           32.000000             6700.000000
# 4          11.6           35.000000             7300.000000
# 5          12.2           39.000000             7800.000000
# 6          12.4           36.000000             7561.191684
# 7          12.4           44.000000             6900.000000
# 8          10.8           33.000000             9600.000000
# 9           9.5           29.000000            12100.000000
# 10          9.4           28.000000            10028.033374
# 11         10.8           32.000000             4500.000000
# 12          9.7           28.000000            12200.000000
# 13          9.8           30.219982             9348.000531
# 14          5.6           16.000000            11000.000000
# 15          7.6           24.000000             3800.000000
# 16         12.6           38.744912             8670.893738
# 17         12.1           37.127233             8677.247105
# 18         12.7           37.000000            11400.000000
# 19         10.3           30.000000             5300.000000
#
#     red_blood_cell_count  hypertension  diabetes_mellitus  \
# 0               5.200000           yes                yes
# 1               4.337269            no                 no
# 2               3.751282            no                yes
# 3               3.900000           yes                 no
# 4               4.600000            no                 no
# 5               4.400000           yes                yes
# 6               4.114364            no                 no
# 7               5.000000            no                yes
# 8               4.000000           yes                yes
# 9               3.700000           yes                yes
# 10              3.564245           yes                yes
# 11              3.800000           yes                yes
# 12              3.400000           yes                yes
# 13              3.647633           yes                yes
# 14              2.600000           yes                yes
# 15              2.800000           yes                 no
# 16              4.553690            no                 no
# 17              4.400139           yes                 no
# 18              4.300000           yes                yes
# 19              3.700000           yes                 no
#
#     coronary_artery_disease  appetite pedal_edema anemia
# 0                        no      good          no     no
# 1                        no      good          no     no
# 2                        no      poor          no    yes
# 3                        no      poor         yes    yes
# 4                        no      good          no     no
# 5                        no      good         yes     no
# 6                        no      good          no     no
# 7                        no      good         yes     no
# 8                        no      good          no    yes
# 9                        no      poor          no    yes
# 10                       no      good          no    yes
# 11                       no      poor         yes     no
# 12                      yes      poor         yes     no
# 13                      yes      poor         yes     no
# 14                      yes      poor         yes     no
# 15                       no      good          no    yes
# 16                       no      good          no     no
# 17                       no      poor          no     no
# 18                      yes      good          no     no
# 19                      yes      good          no     no
#
# [20 rows x 24 columns]

# %% [markdown]
# Ahora, los datos de entrenamiento  están listos.
