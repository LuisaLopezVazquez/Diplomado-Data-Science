# %% [markdown]
# <h2><font color="#004D7F" size=6>Módulo 4. Machine Learning</font></h2>
#
#
#
# <h1><font color="#004D7F" size=5> One Hot Encoding</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#004D7F" size=3>Luisa López Vázquez</font><br>
# <font color="#004D7F" size=3>Diplomado en Ciencia de Datos</font><br>

# %% [markdown]
# Implementación de One Hot Encoding en un data set relacionado a Recursos Humanos, en las variables de "Sexo" y "Ciudadanía".

# %%
import pandas as pd
import numpy as np

# %%
df_rh = pd.read_csv("HRDataset_v14.csv")

# %%
#Mostrar los datos
df_rh.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
#Crear un nuevo data set
df_rh1=df_rh[['Employee_Name','Position','State','Sex','DOB','MaritalDesc',
        'CitizenDesc','Department','PerformanceScore','EngagementSurvey','EmpSatisfaction']]

# %%
#Ver el tamaño
df_rh1.shape
# Out:
# (311, 11)

# %%
#Hacer un describe
df_rh1.describe()
# Out:
#        EngagementSurvey  EmpSatisfaction
# count        311.000000       311.000000
# mean           4.110000         3.890675
# std            0.789938         0.909241
# min            1.120000         1.000000
# 25%            3.690000         3.000000
# 50%            4.280000         4.000000
# 75%            4.700000         5.000000
# max            5.000000         5.000000

# %%
#Hacer un head()
df_rh1.head()
# Out:
#               Employee_Name                  Position State Sex       DOB  \
# 0       Adinolfi, Wilson  K   Production Technician I    MA  M   07/10/83
# 1  Ait Sidi, Karthikeyan                      Sr. DBA    MA  M   05/05/75
# 2         Akinkuolie, Sarah  Production Technician II    MA   F  09/19/88
# 3              Alagbe,Trina   Production Technician I    MA   F  09/27/88
# 4          Anderson, Carol    Production Technician I    MA   F  09/08/89
#
#   MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0      Single  US Citizen  Production                 Exceeds
# 1     Married  US Citizen              IT/IS      Fully Meets
# 2     Married  US Citizen  Production             Fully Meets
# 3     Married  US Citizen  Production             Fully Meets
# 4    Divorced  US Citizen  Production             Fully Meets
#
#    EngagementSurvey  EmpSatisfaction
# 0              4.60                5
# 1              4.96                3
# 2              3.02                3
# 3              4.84                5
# 4              5.00                4

# %%
#Crear datos dummys de la columna sex
dummy_sex=pd.get_dummies(df_rh1['Sex'], prefix='sexo')

# %%
#Vemos que contiene
dummy_sex.head(10)
# Out:
#    sexo_F  sexo_M
# 0       0        1
# 1       0        1
# 2       1        0
# 3       1        0
# 4       1        0
# 5       1        0
# 6       1        0
# 7       0        1
# 8       1        0
# 9       0        1

# %%
#Eliminamos la anterior columna
df_rh1 = df_rh1.drop(['Sex'], axis=1)

# %%
#vemos el tamaño
df_rh1.shape
# Out:
# (311, 10)

# %%
#Concatenamos el dataframe
df_rh2=pd.concat([df_rh1,dummy_sex], axis=1)

# %%
#Vemos el tamaña
df_rh2.shape
# Out:
# (311, 12)

# %%
#Hacemos un head()
df_rh2.head()
# Out:
#               Employee_Name                  Position State       DOB  \
# 0       Adinolfi, Wilson  K   Production Technician I    MA  07/10/83
# 1  Ait Sidi, Karthikeyan                      Sr. DBA    MA  05/05/75
# 2         Akinkuolie, Sarah  Production Technician II    MA  09/19/88
# 3              Alagbe,Trina   Production Technician I    MA  09/27/88
# 4          Anderson, Carol    Production Technician I    MA  09/08/89
#
#   MaritalDesc CitizenDesc         Department PerformanceScore  \
# 0      Single  US Citizen  Production                 Exceeds
# 1     Married  US Citizen              IT/IS      Fully Meets
# 2     Married  US Citizen  Production             Fully Meets
# 3     Married  US Citizen  Production             Fully Meets
# 4    Divorced  US Citizen  Production             Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  sexo_F  sexo_M
# 0              4.60                5       0        1
# 1              4.96                3       0        1
# 2              3.02                3       1        0
# 3              4.84                5       1        0
# 4              5.00                4       1        0

# %%
#Creamos una funcion para cambiar a numerica la ciudadania
def creardatos(df_rh2,varname):
    dummy=pd.get_dummies(df[varname], prefix=varname) #genera los datos de prueba
    df=df_rh2.drop(varname, axis=1) # elimina
    df=pd.concat([df,dummy], axis=1)# hace la union
    return df

# %%
#llamamos la funcion createdummies
#Le pasamos el dataframe que deseamos modificar df_rh2
#Le pasamos la columna que deseamos cambiar "CitizenDesc"
df_final=creardatos(df_rh2,'CitizenDesc')

# %%
df_final.head(20)
# Out:
#                Employee_Name                  Position State       DOB  \
# 0        Adinolfi, Wilson  K   Production Technician I    MA  07/10/83
# 1   Ait Sidi, Karthikeyan                      Sr. DBA    MA  05/05/75
# 2          Akinkuolie, Sarah  Production Technician II    MA  09/19/88
# 3               Alagbe,Trina   Production Technician I    MA  09/27/88
# 4           Anderson, Carol    Production Technician I    MA  09/08/89
# 5          Anderson, Linda     Production Technician I    MA  05/22/77
# 6            Andreola, Colby         Software Engineer    MA  05/24/79
# 7                Athwal, Sam   Production Technician I    MA  02/18/83
# 8           Bachiochi, Linda   Production Technician I    MA  02/11/70
# 9         Bacong, Alejandro                 IT Support    MA  01/07/88
# 10      Baczenski, Rachael     Production Technician I    MA  01/12/74
# 11           Barbara, Thomas   Production Technician I    MA  02/21/74
# 12          Barbossa, Hector              Data Analyst    TX  07/04/88
# 13      Barone, Francesco  A   Production Technician I    MA  07/20/83
# 14             Barton, Nader   Production Technician I    MA  07/15/77
# 15             Bates, Norman   Production Technician I    MA  10/18/81
# 16          Beak, Kimberly    Production Technician II    MA  04/17/66
# 17       Beatrice, Courtney    Production Technician I    MA  10/27/70
# 18             Becker, Renee    Database Administrator    MA  04/04/86
# 19             Becker, Scott   Production Technician I    MA  04/06/79
#
#    MaritalDesc            Department PerformanceScore  EngagementSurvey  \
# 0       Single     Production                 Exceeds              4.60
# 1      Married                 IT/IS      Fully Meets              4.96
# 2      Married     Production             Fully Meets              3.02
# 3      Married     Production             Fully Meets              4.84
# 4     Divorced     Production             Fully Meets              5.00
# 5       Single     Production                 Exceeds              5.00
# 6       Single  Software Engineering      Fully Meets              3.04
# 7      Widowed     Production             Fully Meets              5.00
# 8       Single     Production             Fully Meets              4.46
# 9     Divorced                 IT/IS      Fully Meets              5.00
# 10     Married     Production             Fully Meets              4.20
# 11     Married     Production             Fully Meets              4.20
# 12    Divorced                 IT/IS          Exceeds              4.28
# 13      Single     Production             Fully Meets              4.60
# 14    Divorced     Production             Fully Meets              5.00
# 15      Single     Production             Fully Meets              5.00
# 16     Married     Production                 Exceeds              4.40
# 17      Single     Production             Fully Meets              5.00
# 18      Single                 IT/IS      Fully Meets              4.50
# 19      Single     Production             Fully Meets              4.20
#
#     EmpSatisfaction  sexo_F  sexo_M   CitizenDesc_Eligible NonCitizen  \
# 0                 5       0        1                                0
# 1                 3       0        1                                0
# 2                 3       1        0                                0
# 3                 5       1        0                                0
# 4                 4       1        0                                0
# 5                 5       1        0                                0
# 6                 3       1        0                                0
# 7                 4       0        1                                0
# 8                 3       1        0                                0
# 9                 5       0        1                                0
# 10                4       1        0                                0
# 11                3       0        1                                0
# 12                4       0        1                                0
# 13                4       0        1                                0
# 14                5       0        1                                0
# 15                4       0        1                                0
# 16                3       1        0                                0
# 17                5       1        0                                1
# 18                4       1        0                                0
# 19                4       0        1                                0
#
#     CitizenDesc_Non-Citizen  CitizenDesc_US Citizen
# 0                         0                       1
# 1                         0                       1
# 2                         0                       1
# 3                         0                       1
# 4                         0                       1
# 5                         0                       1
# 6                         0                       1
# 7                         0                       1
# 8                         0                       1
# 9                         0                       1
# 10                        0                       1
# 11                        0                       1
# 12                        0                       1
# 13                        0                       1
# 14                        0                       1
# 15                        0                       1
# 16                        0                       1
# 17                        0                       0
# 18                        0                       1
# 19                        0                       1

# %% [markdown]
# ### Conclusión

# %% [markdown]
# En el último resultado podemos observar la implementación completa del ONE HOT ENCODING en las variables de "Sexo" y "Ciudadanía"
#
# Esta tecnica es parte del prepocesamiento de datos antes de realizar algun modelo predictivo
