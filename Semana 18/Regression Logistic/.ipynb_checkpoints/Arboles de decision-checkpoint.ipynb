# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Cargamos el conjunto de datos

# %%
#Dividimos el conjunto de datos en conjunto de entrenamiento y conjunto de pruebas

# %%
# Estandarización de los datos  mediante las  escalas
from sklearn.preprocessing import StandardScaler

# %%
#Regresión logistica y entrenamiento del modelo
from sklearn.linear_model import LogisticRegression

# %%
#Predicción del conjunto de pruebas

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix

# %% [markdown]
# confuxion matreiz,
# observamos dos clase 0/1
# hay 65 valores que eran 0 los prdijo como cero
# 3 valores que eran 0 los predijo como 1
#
# 8 valores que  eran 1 los predijo como cero
# 24 era cero y los predijo como cero
#
# en la diagonal tenemos los valores clasificados correctamente
#
# 65 + 24 = 89 fueron predicidos correctamente

# %%
#Obtenemos el score

# %%
#89 % de asiertos que obtuvo nuestro modelo

# %%
#Arboles de decision
#Entropia sinonimo de insertidumbre
#Usamos este esquema para disminuir la entropia y aumentar la probalidad
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ![imagen.png](attachment:796eef93-a3f5-4720-b9d0-d1212a36c4cd.png)

# %%
#Obtenemos el score de clasificar por arbol 
#Tenemos 91 % de asiertos

# %% [markdown]
# Esto tambien depende de la cantidad de datos que estamos usando
# podemos ajustar si tenemos mas datos tendremos un entranamiento mas preciso

# %%
#Visualización de los resultados de prueba
from matplotlib.colors import ListedColormap

# %% [markdown]
# https://www.youtube.com/watch?v=AahwyCvQx00

# %% [markdown]
# https://www.tokioschool.com/noticias/algoritmo-arbol-decision/
