# %%
#Importar libreria para trabajar con fechas
import datetime

# %%
# Declarar una fecha
fecha = datetime.date(2023,1,6)

# %%
fecha
# Out:
# datetime.date(2023, 1, 6)

# %%
#Obtener el año de una fecha
fecha.year
# Out:
# 2023

# %%
#Obtener el mes de una fecha
fecha.month
# Out:
# 1

# %%
#Obtener el dia de una fecha
fecha.day
# Out:
# 6

# %% [markdown]
# date.today(): para obtener la fecha de hoy.

# %%
# Obtener la fecha actual
fecha= datetime.date.today()
print(fecha)
# Out:
# 2023-04-26

# %% [markdown]
# date.replace(): cambia el año, mes y/o día de una fecha según especifiquemos respectivamente con los parámetros year, month y day

# %%
fecha = datetime.date(2021, 7, 22)
print(fecha)
# Out:
# 2021-07-22

# %%
fecha = fecha.replace(day=24)

# %%
print(fecha)
# Out:
# 2021-07-24

# %% [markdown]
# date.isoweekday(): retorna un entero entre 1 y 7 que representa el día de la semana de la fecha,
# siendo:
# 1 = lunes y 7 domingo

# %%
#Obtener el numero de dia en una semana 
fecha.isoweekday()
# Out:
# 6

# %% [markdown]
# Crear una objeto time es similar a lo que ya hemos visto con la clase date. Es decir, tenemos que especificar las horas, minutos, segundos y microsegundos que tiene nuestra hora. Si no especificamos alguno de estos parámetros se asume que su valor es 0. Además, hemos de tener en cuenta que las horas son en formato 24 horas. De este modo, para crear un objeto time que represente las nueve y cuarto de la noche lo haríamos así

# %%
#Declarar una hora
hora = datetime.time(21, 15, 30)
print(hora)
# Out:
# 21:15:30

# %%
#Obtener la hora
hora.hour
# Out:
# 21

# %%
#Obtener los miutos 
hora.minute
# Out:
# 15

# %%
#Obtener los segundos
hora.second
# Out:
# 30

# %%
#Dar formato a la hora
hora = datetime.time(21,15)
hora.isoformat()
# Out:
# '21:15:00'

# %% [markdown]
# Formatear fechas y horas
#
# En esta sección vamos a ver dos métodos especiales de las clases date, time y datetime. Uno para representarlos en una cadena de caracteres (o string) formateado a nuestro gusto, y otro para crear instancias de estos objetos a partir de un string.

# %%
#Esta clase permite representar una fecha con una hora asociada
from datetime import datetime

# %%
#Dar formato a una fecha e imprimirla
fecha = datetime(2023,1,6,20,15)
fechaFomateada = fecha.strftime('%A, %d de %B %Y las %I:%M')
print(fechaFomateada)
# Out:
# Friday, 06 de January 2023 las 08:15

# %%
#Canbiar el idioma
import locale
locale.setlocale(locale.LC_TIME,"es_ES")
# Out:
# 'es_ES'

# %%
#Dar formato a una fecha e imprimirla despues de cambiar el idioma
fecha = datetime.date.today()
print(fecha)
# Out:
# 2023-04-26

# %%
fechaFomateada = fecha.strftime('%A, %d de %B %Y')
print(fechaFomateada)
# Out:
# miércoles, 26 de abril 2023

# %%
from datetime import datetime
fecha = datetime(2023, 1, 6)
fechaFormateada = fecha.strftime("%A, %d de %B %Y las %I:%M")
print(fechaFormateada)
# Out:
# viernes, 06 de enero 2023 las 12:00

# %% [markdown]
# ![imagen.png](attachment:5a5bfdea-3604-440f-81f5-d3461968606c.png)
