# %% [markdown]
# <h1 style="color:purple"> Medidas de Dispersión con Numpy </h1>

# %% [markdown]
# ![imagen.png](attachment:1a8e3db1-9d46-48e1-a65c-98d7d5b02f9d.png)

# %% [markdown]
# ![imagen.png](attachment:f97c82ae-e379-4639-8aaa-7e5fa1253ffe.png)

# %% [markdown]
# ![imagen.png](attachment:1117548f-e97f-4359-a6c3-230a1c85e5cb.png)

# %% [markdown]
# ![imagen.png](attachment:b3d16c34-c46f-4a96-80c8-c2694581acd9.png)

# %% [markdown]
# ![imagen.png](attachment:79110af0-0949-4369-b36e-cf56fc95b8a2.png)

# %% [markdown]
# ![imagen.png](attachment:027b84a9-1e92-4b4f-9ad2-e3ec7af2da35.png)

# %% [markdown]
# ![imagen.png](attachment:9e2167b6-c3ca-4286-bd92-44dccd8fe843.png)

# %%
import numpy as np
