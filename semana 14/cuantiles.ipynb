# %% [markdown]
# <h1 style="color:purple"> Cálculo de los cuantiles con Numpy </h1>

# %% [markdown]
# ![imagen.png](attachment:0893256c-74ad-443a-9fa5-05e6039dd3e3.png)

# %% [markdown]
# ![imagen.png](attachment:6e70aafb-7db8-492c-8e49-7d5c2e4d364a.png)

# %% [markdown]
# ![imagen.png](attachment:de639867-3544-4acc-ac3b-8481c173cdf3.png)

# %% [markdown]
# ![imagen.png](attachment:8abe7e28-ba99-4df1-8e2d-ca03315c761e.png)

# %% [markdown]
# ![imagen.png](attachment:fc603699-e05d-4c7f-b183-afd894a128bc.png)

# %% [markdown]
# ![imagen.png](attachment:d1b6c19b-cdc9-4590-8bfa-bc26b31d6403.png)

# %% [markdown]
# ![imagen.png](attachment:a5d8f5fe-2f28-4b30-b301-fa3bf22b92a4.png)

# %%
import numpy as np

# %% [markdown]
# <h1 style="color:purple"> Graficando los Cuantiles </h1>

# %%
import matplotlib.pyplot as plt
